# %%
from datetime import datetime
import numpy as np

# %%
T = 1000
for t in range(T):
    arr_a = np.random.choice(10, size = (t,t))
    arr_b = np.random.choice(10, size = (t,t))
    arr_c = np.zeros((t,t))
    
    a_list = arr_a.tolist()
    b_list = arr_b.tolist()
    c_list = arr_c.tolist()
    
    t0 = datetime.now()
    arr_c = np.dot(arr_a, arr_b)
    dt0 = datetime.now() - t0
    
    t1 = datetime.now()
    for i in range(len(a_list)):
        for j in range(len(b_list[0])):
            for k in range(len(b_list)):
                c_list[i][j] += a_list[i][k] * b_list[k][j]
    dt1 = datetime.now() - t0
    
    print('array ', end = '')
    print(t, end = '')
    print(' = ', end = '')
    print(dt0)
    
    print('list ', end = '')
    print(t, end = '')
    print(' = ', end = '')
    print(dt1)
# Out:
# array 0 = 0:00:00
# list 0 = 0:00:00
# array 1 = 0:00:00
# list 1 = 0:00:00
# array 2 = 0:00:00
# list 2 = 0:00:00
# array 3 = 0:00:00
# list 3 = 0:00:00
# array 4 = 0:00:00
# list 4 = 0:00:00
# array 5 = 0:00:00
# list 5 = 0:00:00
# array 6 = 0:00:00
# list 6 = 0:00:00
# array 7 = 0:00:00
# list 7 = 0:00:00
# array 8 = 0:00:00
# list 8 = 0:00:00.000631
# array 9 = 0:00:00
# list 9 = 0:00:00.001003
# array 10 = 0:00:00
# list 10 = 0:00:00.001002
# array 11 = 0:00:00
# list 11 = 0:00:00.000997
# array 12 = 0:00:00
# list 12 = 0:00:00.001001
# array 13 = 0:00:00.001002
# list 13 = 0:00:00.002003
# array 14 = 0:00:00.001001
# list 14 = 0:00:00.001999
# array 15 = 0:00:00
# list 15 = 0:00:00.002013
# array 16 = 0:00:00
# list 16 = 0:00:00.002002
# array 17 = 0:00:00.001882
# list 17 = 0:00:00.004883
# array 18 = 0:00:00
# list 18 = 0:00:00.003011
# array 19 = 0:00:00.001019
# list 19 = 0:00:00.004020
# array 20 = 0:00:00
# list 20 = 0:00:00.004011
# array 21 = 0:00:00
# list 21 = 0:00:00.005021
# array 22 = 0:00:00
# list 22 = 0:00:00.005020
# array 23 = 0:00:00
# list 23 = 0:00:00.006020
# array 24 = 0:00:00
# list 24 = 0:00:00.009002
# array 25 = 0:00:00
# list 25 = 0:00:00.007997
# array 26 = 0:00:00
# list 26 = 0:00:00.009001
# array 27 = 0:00:00
# list 27 = 0:00:00.010011
# array 28 = 0:00:00
# list 28 = 0:00:00.015003
# array 29 = 0:00:00
# list 29 = 0:00:00.016003
# array 30 = 0:00:00
# list 30 = 0:00:00.014003
# array 31 = 0:00:00
# list 31 = 0:00:00.016004
# array 32 = 0:00:00
# list 32 = 0:00:00.016004
# array 33 = 0:00:00
# list 33 = 0:00:00.017004
# array 34 = 0:00:00
# list 34 = 0:00:00.024005
# array 35 = 0:00:00
# list 35 = 0:00:00.024006
# array 36 = 0:00:00
# list 36 = 0:00:00.032007
# array 37 = 0:00:00.001000
# list 37 = 0:00:00.026006
# array 38 = 0:00:00.001000
# list 38 = 0:00:00.028986
# array 39 = 0:00:00.001002
# list 39 = 0:00:00.031008
# array 40 = 0:00:00
# list 40 = 0:00:00.034007
# array 41 = 0:00:00
# list 41 = 0:00:00.046009
# array 42 = 0:00:00
# list 42 = 0:00:00.057015
# array 43 = 0:00:00.001000
# list 43 = 0:00:00.048010
# array 44 = 0:00:00
# list 44 = 0:00:00.045009
# array 45 = 0:00:00
# list 45 = 0:00:00.054032
# array 46 = 0:00:00.001004
# list 46 = 0:00:00.052011
# array 47 = 0:00:00
# list 47 = 0:00:00.063033
# array 48 = 0:00:00
# list 48 = 0:00:00.059012
# array 49 = 0:00:00.001000
# list 49 = 0:00:00.059032
# array 50 = 0:00:00.000999
# list 50 = 0:00:00.064013
# array 51 = 0:00:00
# list 51 = 0:00:00.067032
# array 52 = 0:00:00
# list 52 = 0:00:00.076015
# array 53 = 0:00:00
# list 53 = 0:00:00.075016
# array 54 = 0:00:00
# list 54 = 0:00:00.117046
# array 55 = 0:00:00
# list 55 = 0:00:00.129024
# array 56 = 0:00:00
# list 56 = 0:00:00.120025
# array 57 = 0:00:00.001014
# list 57 = 0:00:00.117038
# array 58 = 0:00:00
# list 58 = 0:00:00.099021
# array 59 = 0:00:00
# list 59 = 0:00:00.109042
# array 60 = 0:00:00
# list 60 = 0:00:00.110022
# array 61 = 0:00:00.001000
# list 61 = 0:00:00.131029
# array 62 = 0:00:00
# list 62 = 0:00:00.123038
# array 63 = 0:00:00.000999
# list 63 = 0:00:00.122025
# array 64 = 0:00:00
# list 64 = 0:00:00.132028
# array 65 = 0:00:00
# list 65 = 0:00:00.141031
# array 66 = 0:00:00
# list 66 = 0:00:00.152055
# array 67 = 0:00:00.001000
# list 67 = 0:00:00.171033
# array 68 = 0:00:00
# list 68 = 0:00:00.158034
# array 69 = 0:00:00
# list 69 = 0:00:00.168038
# array 70 = 0:00:00
# list 70 = 0:00:00.191063
# array 71 = 0:00:00.001000
# list 71 = 0:00:00.183040
# array 72 = 0:00:00.001001
# list 72 = 0:00:00.197044
# array 73 = 0:00:00
# list 73 = 0:00:00.202045
# array 74 = 0:00:00
# list 74 = 0:00:00.211047
# array 75 = 0:00:00.002000
# list 75 = 0:00:00.218046
# array 76 = 0:00:00
# list 76 = 0:00:00.240053
# array 77 = 0:00:00
# list 77 = 0:00:00.239054
# array 78 = 0:00:00.000999
# list 78 = 0:00:00.289083
# array 79 = 0:00:00.001000
# list 79 = 0:00:00.295066
# array 80 = 0:00:00
# list 80 = 0:00:00.277081
# array 81 = 0:00:00.000998
# list 81 = 0:00:00.275056
# array 82 = 0:00:00
# list 82 = 0:00:00.313082
# array 83 = 0:00:00.000998
# list 83 = 0:00:00.269057
# array 84 = 0:00:00
# list 84 = 0:00:00.272079
# array 85 = 0:00:00.000996
# list 85 = 0:00:00.273042
# array 86 = 0:00:00
# list 86 = 0:00:00.313068
# array 87 = 0:00:00
# list 87 = 0:00:00.308067
# array 88 = 0:00:00.001001
# list 88 = 0:00:00.335072
# array 89 = 0:00:00
# list 89 = 0:00:00.320091
# array 90 = 0:00:00.001002
# list 90 = 0:00:00.328092
# array 91 = 0:00:00.001000
# list 91 = 0:00:00.345056
# array 92 = 0:00:00
# list 92 = 0:00:00.358077
# array 93 = 0:00:00.001000
# list 93 = 0:00:00.357080
# array 94 = 0:00:00
# list 94 = 0:00:00.390086
# array 95 = 0:00:00
# list 95 = 0:00:00.434096
# array 96 = 0:00:00
# list 96 = 0:00:00.401099
# array 97 = 0:00:00.001000
# list 97 = 0:00:00.478087
# array 98 = 0:00:00.000999
# list 98 = 0:00:00.443098
# array 99 = 0:00:00.001000
# list 99 = 0:00:00.484110
# array 100 = 0:00:00
# list 100 = 0:00:00.534119
# array 101 = 0:00:00.001000
# list 101 = 0:00:00.459122
# array 102 = 0:00:00.001999
# list 102 = 0:00:00.505112
# array 103 = 0:00:00.001001
# list 103 = 0:00:00.513135
# array 104 = 0:00:00.001002
# list 104 = 0:00:00.518117
# array 105 = 0:00:00.001000
# list 105 = 0:00:00.542132
# array 106 = 0:00:00.001010
# list 106 = 0:00:00.536121
# array 107 = 0:00:00
# list 107 = 0:00:00.567126
# array 108 = 0:00:00
# list 108 = 0:00:00.567115
# array 109 = 0:00:00.001000
# list 109 = 0:00:00.597134
# array 110 = 0:00:00.001000
# list 110 = 0:00:00.631142
# array 111 = 0:00:00.001000
# list 111 = 0:00:00.659147
# array 112 = 0:00:00.000999
# list 112 = 0:00:00.629140
# array 113 = 0:00:00.001002
# list 113 = 0:00:00.635162
# array 114 = 0:00:00.000999
# list 114 = 0:00:00.717179
# array 115 = 0:00:00.001000
# list 115 = 0:00:00.709150
# array 116 = 0:00:00.001000
# list 116 = 0:00:00.841311
# array 117 = 0:00:00.002001
# list 117 = 0:00:00.726162
# array 118 = 0:00:00.002000
# list 118 = 0:00:00.773191
# array 119 = 0:00:00.000986
# list 119 = 0:00:00.735144
# array 120 = 0:00:00.001999
# list 120 = 0:00:00.870214
# array 121 = 0:00:00.002000
# list 121 = 0:00:00.827165
# array 122 = 0:00:00.001000
# list 122 = 0:00:00.857193
# array 123 = 0:00:00.001000
# list 123 = 0:00:00.917206
# array 124 = 0:00:00.002001
# list 124 = 0:00:00.862193
# array 125 = 0:00:00.000999
# list 125 = 0:00:00.956281
# array 126 = 0:00:00.002000
# list 126 = 0:00:00.877197
# array 127 = 0:00:00.001002
# list 127 = 0:00:01.011245
# array 128 = 0:00:00.003001
# list 128 = 0:00:00.965199
# array 129 = 0:00:00.001000
# list 129 = 0:00:00.929207
# array 130 = 0:00:00.002000
# list 130 = 0:00:01.077250
# array 131 = 0:00:00.002001
# list 131 = 0:00:00.999224
# array 132 = 0:00:00.001983
# list 132 = 0:00:01.020228
# array 133 = 0:00:00.002000
# list 133 = 0:00:01.060238
# array 134 = 0:00:00.001999
# list 134 = 0:00:01.131253
# array 135 = 0:00:00.001999
# list 135 = 0:00:01.136274
# array 136 = 0:00:00.001000
# list 136 = 0:00:01.262394
# array 137 = 0:00:00.000998
# list 137 = 0:00:01.147259
# array 138 = 0:00:00.002000
# list 138 = 0:00:01.159384
# array 139 = 0:00:00.002001
# list 139 = 0:00:01.211291
# array 140 = 0:00:00.000990
# list 140 = 0:00:01.222273
# array 141 = 0:00:00.002000
# list 141 = 0:00:01.230256
# array 142 = 0:00:00.001998
# list 142 = 0:00:01.277283
# array 143 = 0:00:00.002000
# list 143 = 0:00:01.293289
# array 144 = 0:00:00.002000
# list 144 = 0:00:01.384310
# array 145 = 0:00:00.001999
# list 145 = 0:00:01.447322
# array 146 = 0:00:00.002006
# list 146 = 0:00:01.402300
# array 147 = 0:00:00.000998
# list 147 = 0:00:01.473329
# array 148 = 0:00:00.001998
# list 148 = 0:00:01.435339
# array 149 = 0:00:00.002000
# list 149 = 0:00:01.525342
# array 150 = 0:00:00.001990
# list 150 = 0:00:01.532342
# array 151 = 0:00:00.002000
# list 151 = 0:00:01.551329
# array 152 = 0:00:00.003000
# list 152 = 0:00:01.607361
# array 153 = 0:00:00.001986
# list 153 = 0:00:01.618348
# array 154 = 0:00:00.002998
# list 154 = 0:00:01.685881
# array 155 = 0:00:00.001997
# list 155 = 0:00:01.670371
# array 156 = 0:00:00.003000
# list 156 = 0:00:01.729388
# array 157 = 0:00:00.001999
# list 157 = 0:00:01.737389
# array 158 = 0:00:00.002000
# list 158 = 0:00:01.830410
# array 159 = 0:00:00.004000
# list 159 = 0:00:01.826407
# array 160 = 0:00:00.002999
# list 160 = 0:00:01.834430
# array 161 = 0:00:00.003001
# list 161 = 0:00:01.891412
# array 162 = 0:00:00.003001
# list 162 = 0:00:02.004449
# array 163 = 0:00:00.004012
# list 163 = 0:00:01.931434
# array 164 = 0:00:00.003002
# list 164 = 0:00:02.047459
# array 165 = 0:00:00.002990
# list 165 = 0:00:02.028444
# array 166 = 0:00:00.004000
# list 166 = 0:00:02.091467
# array 167 = 0:00:00.003000
# list 167 = 0:00:02.098490
# array 168 = 0:00:00.003000
# list 168 = 0:00:02.088449
# array 169 = 0:00:00.002998
# list 169 = 0:00:02.131475
# array 170 = 0:00:00.007001
# list 170 = 0:00:02.276515
# array 171 = 0:00:00.004000
# list 171 = 0:00:02.257503
# array 172 = 0:00:00.003001
# list 172 = 0:00:02.309536
# array 173 = 0:00:00.003009
# list 173 = 0:00:02.350535
# array 174 = 0:00:00.004000
# list 174 = 0:00:02.371512
# array 175 = 0:00:00.007982
# list 175 = 0:00:02.434545
# array 176 = 0:00:00.003992
# list 176 = 0:00:02.458531
# array 177 = 0:00:00.004000
# list 177 = 0:00:02.443546
# array 178 = 0:00:00.004001
# list 178 = 0:00:02.542588
# array 179 = 0:00:00.002999
# list 179 = 0:00:02.619585
# array 180 = 0:00:00.004994
# list 180 = 0:00:02.612585
# array 181 = 0:00:00.003992
# list 181 = 0:00:02.575559
# array 182 = 0:00:00.003999
# list 182 = 0:00:02.688621
# array 183 = 0:00:00.004001
# list 183 = 0:00:02.746597
# array 184 = 0:00:00.004001
# list 184 = 0:00:02.832634
# array 185 = 0:00:00.004008
# list 185 = 0:00:02.798635
# array 186 = 0:00:00.005001
# list 186 = 0:00:02.906635
# array 187 = 0:00:00.004000
# list 187 = 0:00:03.025915
# array 188 = 0:00:00.005001
# list 188 = 0:00:03.015656
# array 189 = 0:00:00.004990
# list 189 = 0:00:03.057694
# array 190 = 0:00:00.004000
# list 190 = 0:00:03.072683
# array 191 = 0:00:00.004989
# list 191 = 0:00:03.245716
# array 192 = 0:00:00.006000
# list 192 = 0:00:03.186715
# array 193 = 0:00:00.005000
# list 193 = 0:00:03.234723
# array 194 = 0:00:00.005000
# list 194 = 0:00:03.270890
# array 195 = 0:00:00.005001
# list 195 = 0:00:03.301760
# array 196 = 0:00:00.005009
# list 196 = 0:00:03.332736
# array 197 = 0:00:00.005000
# list 197 = 0:00:03.529789
# array 198 = 0:00:00.005999
# list 198 = 0:00:03.442789
# array 199 = 0:00:00.005001
# list 199 = 0:00:03.494783
# array 200 = 0:00:00.006002
# list 200 = 0:00:03.705834
# array 201 = 0:00:00.009001
# list 201 = 0:00:03.669841
# array 202 = 0:00:00.006026
# list 202 = 0:00:03.854883
# array 203 = 0:00:00.005001
# list 203 = 0:00:03.809834
# array 204 = 0:00:00.006000
# list 204 = 0:00:03.894968
# array 205 = 0:00:00.007002
# list 205 = 0:00:03.911878
# array 206 = 0:00:00.005998
# list 206 = 0:00:04.016985
# array 207 = 0:00:00.006000
# list 207 = 0:00:04.060909
# array 208 = 0:00:00.006010
# list 208 = 0:00:04.023893
# array 209 = 0:00:00.007000
# list 209 = 0:00:04.042906
# array 210 = 0:00:00.006002
# list 210 = 0:00:04.107921
# array 211 = 0:00:00.006997
# list 211 = 0:00:04.248967
# array 212 = 0:00:00.007010
# list 212 = 0:00:04.333487
# array 213 = 0:00:00.006000
# list 213 = 0:00:04.353994
# array 214 = 0:00:00.013984
# list 214 = 0:00:04.482986
# array 215 = 0:00:00.007998
# list 215 = 0:00:04.427008
# array 216 = 0:00:00.006001
# list 216 = 0:00:04.575026
# array 217 = 0:00:00.014003
# list 217 = 0:00:04.599031
# array 218 = 0:00:00.006998
# list 218 = 0:00:04.797072
# array 219 = 0:00:00.005999
# list 219 = 0:00:04.634028
# array 220 = 0:00:00.007009
# list 220 = 0:00:04.753055
# array 221 = 0:00:00.009001
# list 221 = 0:00:04.840239
# array 222 = 0:00:00.007998
# list 222 = 0:00:04.848083
# array 223 = 0:00:00.008001
# list 223 = 0:00:05.180276
# array 224 = 0:00:00.007001
# list 224 = 0:00:04.968176
# array 225 = 0:00:00.008002
# list 225 = 0:00:05.365222
# array 226 = 0:00:00.008009
# list 226 = 0:00:05.194378
# array 227 = 0:00:00.008009
# list 227 = 0:00:05.337184
# array 228 = 0:00:00.008002
# list 228 = 0:00:05.371727
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-a7e4668b502a> in <module>
#      17         for j in range(len(b_list[0])):
#      18             for k in range(len(b_list)):
# ---> 19                 c_list[i][j] += a_list[i][k] * b_list[k][j]
#      20     dt1 = datetime.now() - t0
#      21
#
# KeyboardInterrupt:
